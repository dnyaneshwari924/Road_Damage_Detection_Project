# %%
import torch

print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA: True
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.4.127

# %%
from pathlib import Path

dataset_path = Path(r"C:/Users/Dnyaneshwari Jogdand/Documents/AI_Road_Damage/archive/data/road_dataset")

print("Train images:", len(list((dataset_path / "train/images").glob("*"))))
print("Train labels:", len(list((dataset_path / "train/labels").glob("*.txt"))))

print("Val images:", len(list((dataset_path / "val/images").glob("*"))))
print("Val labels:", len(list((dataset_path / "val/labels").glob("*.txt"))))
# Out:
# Train images: 1607
# Train labels: 1607
# Val images: 402
# Val labels: 402

# %%
from ultralytics import YOLO

print("Ultralytics YOLO imported successfully!")
# Out:
# Ultralytics YOLO imported successfully!

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

print("YOLO model loaded successfully!")
# Out:
# YOLO model loaded successfully!

# %%
from pathlib import Path

yaml_path = Path(r"C:/Users/Dnyaneshwari Jogdand/Documents/AI_Road_Damage/data.yaml")

print("data.yaml exists:", yaml_path.exists())
print("Path:", yaml_path)
# Out:
# data.yaml exists: True
# Path: C:\Users\Dnyaneshwari Jogdand\Documents\AI_Road_Damage\data.yaml

# %%
from pathlib import Path

dataset = Path(r"C:/Users/Dnyaneshwari Jogdand/Documents/AI_Road_Damage/archive/data/road_dataset")

for cache in dataset.rglob("*.cache"):
    print("Deleting:", cache)
    cache.unlink()

print("Cache files deleted.")
# Out:
# Deleting: C:\Users\Dnyaneshwari Jogdand\Documents\AI_Road_Damage\archive\data\road_dataset\train\labels.cache
# Deleting: C:\Users\Dnyaneshwari Jogdand\Documents\AI_Road_Damage\archive\data\road_dataset\val\labels.cache
# Deleting: C:\Users\Dnyaneshwari Jogdand\Documents\AI_Road_Damage\archive\data\road_dataset\road_dataset\train\labels.cache
# Deleting: C:\Users\Dnyaneshwari Jogdand\Documents\AI_Road_Damage\archive\data\road_dataset\road_dataset\val\labels.cache
# Cache files deleted.

# %%
from pathlib import Path

dataset = Path(r"C:/Users/Dnyaneshwari Jogdand/Documents/AI_Road_Damage/archive/data/road_dataset")

print("Dataset exists:", dataset.exists())
print("Train exists:", (dataset / "train").exists())
print("Val exists:", (dataset / "val").exists())
print("Train images:", len(list((dataset / "train/images").glob("*"))))
print("Train labels:", len(list((dataset / "train/labels").glob("*.txt"))))
print("Val images:", len(list((dataset / "val/images").glob("*"))))
print("Val labels:", len(list((dataset / "val/labels").glob("*.txt"))))
# Out:
# Dataset exists: True
# Train exists: True
# Val exists: True
# Train images: 1607
# Train labels: 1607
# Val images: 402
# Val labels: 402

# %%
from pathlib import Path

dataset = Path(r"C:/Users/Dnyaneshwari Jogdand/Documents/AI_Road_Damage/archive/data/road_dataset")

for cache in dataset.rglob("*.cache"):
    print("Deleting:", cache)
    cache.unlink()

print("Cache files deleted.")
# Out:
# Deleting: C:\Users\Dnyaneshwari Jogdand\Documents\AI_Road_Damage\archive\data\road_dataset\train\labels.cache
# Cache files deleted.

# %%
results = model.train(
    data=r"C:/Users/Dnyaneshwari Jogdand/Documents/AI_Road_Damage/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    workers=0,
    project=r"C:/Users/Dnyaneshwari Jogdand/Documents/AI_Road_Damage/runs",
    name="road_damage_yolo11n",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.127  Python-3.13.15 torch-2.13.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
